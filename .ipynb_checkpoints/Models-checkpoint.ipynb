# %% [markdown]
# # Modeling

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scikitplot as skplt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from imblearn.combine import SMOTEENN
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Convolution2D, MaxPooling2D, Convolution1D, MaxPooling1D
from keras.utils import to_categorical
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier
from keras import regularizers

plt.style.use('fivethirtyeight')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
# Load data
train = pd.read_csv('assets/working/feat_train.csv')
test = pd.read_csv('assets/working/feat_test.csv')
spray = pd.read_csv('assets/working/feat_spray.csv')

# %%
# Define function to ensure equal columns in the train and test datasets (taken from EDA notebook)
def leveller(train, test):
    tr_features = set(train.columns)
    te_features = set(test.columns)
    for missing_col in tr_features - te_features:
        test[missing_col] = 0
    return train, test[train.columns]

# %% [markdown]
# #### Balance Classes

# %% [markdown]
# Since our target variable only makes up for 5% of the data, we will need to artificially balance the classes so that our models perform better. We want to use a combination of under and over sampling, so we will use the SMOTE method to accomplish this.

# %%
# Define X and y
X = train.drop('WnvPresent', axis = 1)
y = train['WnvPresent']

# %%
# Convert Year and Month to Dummies
X = pd.get_dummies(X, columns = ['Month', 'Trap'])

# %%
# Kaggle Submission preprocessing to match 
X_test_kaggle = pd.get_dummies(test, columns = ['Month', 'Trap'])
X_test_kaggle.drop('WnvPresent', axis = 1, inplace = True)
_, X_test_kaggle = leveller(X, X_test_kaggle)

# %%
# Use SMOTE method to balance classes
sme = SMOTEENN()
X_res, y_res = sme.fit_sample(X, y)

# %%
# Check class balance 
pd.Series(y_res).value_counts(normalize = True)
# Out:
# 1    0.625981
# 0    0.374019
# dtype: float64

# %% [markdown]
# With the balanced data, the baseline accuracy score to beat is 50%

# %% [markdown]
# #### Logistic Regression

# %%
# Train test split and standardize data
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, random_state = 42)

ss = StandardScaler()
X_train = ss.fit_transform(X_train)
X_test = ss.transform(X_test)

# %%
# Kaggle Submission preprocessing 
X_test_kaggle_sc = ss.transform(X_test_kaggle)

# %%
# Fit model and accuracy score
logreg = LogisticRegression()
model_logreg = logreg.fit(X_train, y_train)
model_logreg.score(X_train, y_train), model_logreg.score(X_test, y_test)
# Out:
# (0.9084816753926701, 0.9051507537688442)

# %%
# Evaluate model with AUC-ROC score
y_score = model_logreg.predict(X_test)
metrics.roc_auc_score(y_test, y_score)
# Out:
# 0.89067573085909

# %%
# Gridsearch on logistic regression model above
lr_params = {'penalty':['l1', 'l2'], 
             'C': [0.2, 0.3, 0.5]}
gs = GridSearchCV(LogisticRegression(), param_grid = lr_params)
gs.fit(X_train, y_train)

# Results 
gs.best_score_, gs.best_params_
# Out:
# (0.9030366492146596, {'C': 0.5, 'penalty': 'l2'})

# %%
# Gridsearch test accuracy score
gs.score(X_test, y_test)
# Out:
# 0.905464824120603

# %%
# Evaluate gridsearched model with AUC-ROC score
y_score = gs.predict_proba(X_test)[:,1]
metrics.roc_auc_score(y_test, y_score)
# Out:
# 0.9525631949604697

# %% [markdown]
# Gridsearching improved the AUC-ROC score. Neither model was overfit.

# %%
# Determine top predictors in model 
coefs = pd.DataFrame(gs.best_estimator_.coef_[0], index = X.columns, columns = ['coef'])
coefs['coef'] = np.exp(coefs['coef'])
coefs.sort_values(by='coef', ascending = False, inplace=True)
coefs.head()
# Out:
#               coef
# WetBulb  12.848257
# Sunrise  11.250369
# Sunset    5.470034
# Month_8   4.326373
# Year      3.584185

# %%
# ROC Plot 
y_probs = gs.predict_proba(X_test)[:, 1]
fpr, tpr, threshold = metrics.roc_curve(y_test, y_probs)

fig = plt.figure(figsize = (5,5))
plt.plot(fpr, tpr)

# Labels
plt.xlabel('Specificity')
plt.ylabel('Sensitivity')
plt.title('ROC curve');

# %%
# Kaggle predictions dataframe and csv file
submission = pd.DataFrame()
submission['WnvPresent'] = gs.predict(X_test_kaggle_sc)
submission['Id'] = submission.index + 1
submission[['Id', 'WnvPresent']].to_csv('kaggle/submission_logreg.csv', index = False)

# %% [markdown]
# On Kaggle this model achieved a AUC-ROC score of 0.60619

# %% [markdown]
# With 'Year' as a numeric feature and with all species features removed, this model achieved an AuC-RoC Kaggle score of 0.67215

# %% [markdown]
# #### CNN

# %%
# Train test split and standardize data
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, random_state = 42)

ss = StandardScaler()
X_train = ss.fit_transform(X_train)
X_test = ss.transform(X_test)

# %%
# Kaggle Submission preprocessing 
X_test_kaggle_sc = ss.transform(X_test_kaggle)

# %%
# Reshape our NumPy array 
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_test_kaggle_shaped = X_test_kaggle_sc.reshape(X_test_kaggle_sc.shape[0], X_test_kaggle_sc.shape[1], 1)

# Convert dtype from int to float
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_test_kaggle_shaped = X_test_kaggle_shaped.astype('float32')

# %%
# Preprocess Y data
y_train = to_categorical(y_train, 2)
Y_test = to_categorical(y_test, 2 )

# %%
# Define Model Architecture
model = Sequential()
model.add(Convolution1D(filters=10, kernel_size=3, activation="relu", input_shape = (X_train.shape[1],1)))
model.add(MaxPooling1D(pool_size = 2)) 
model.add(Convolution1D(filters=20, kernel_size=3, activation="relu"))
model.add(MaxPooling1D(pool_size = 2)) 
model.add(Convolution1D(filters=30, kernel_size=3, activation="relu"))
model.add(MaxPooling1D(pool_size = 2)) 
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(X_train.shape[1], activation = 'relu', kernel_regularizer=regularizers.l2(0.01))) 
model.add(Dropout(0.5))
model.add(Dense(20, activation = 'relu', kernel_regularizer=regularizers.l2(0.01))) 
model.add(Dropout(0.5))
model.add(Dense(2, activation = 'sigmoid'))

# Compile
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
# Fit model with training data
model.fit(X_train, y_train, batch_size = 32, epochs = 30, verbose = 1)
# Out:
# Epoch 1/50
# 9555/9555 [==============================] - 4s 400us/step - loss: 1.2455 - acc: 0.6932
# Epoch 2/50
# 9555/9555 [==============================] - 4s 384us/step - loss: 0.5024 - acc: 0.8682
# Epoch 3/50
# 9555/9555 [==============================] - 4s 368us/step - loss: 0.3873 - acc: 0.9025
# Epoch 4/50
# 9555/9555 [==============================] - 4s 389us/step - loss: 0.3436 - acc: 0.9132
# Epoch 5/50
# 9555/9555 [==============================] - 4s 385us/step - loss: 0.3028 - acc: 0.9277
# Epoch 6/50
# 9555/9555 [==============================] - 4s 370us/step - loss: 0.2797 - acc: 0.9358
# Epoch 7/50
# 9555/9555 [==============================] - 3s 349us/step - loss: 0.2562 - acc: 0.9421
# Epoch 8/50
# 9555/9555 [==============================] - 3s 338us/step - loss: 0.2445 - acc: 0.9460
# Epoch 9/50
# 9555/9555 [==============================] - 3s 280us/step - loss: 0.2308 - acc: 0.9515
# Epoch 10/50
# 9555/9555 [==============================] - 3s 315us/step - loss: 0.2209 - acc: 0.9509
# Epoch 11/50
# 9555/9555 [==============================] - 3s 264us/step - loss: 0.2066 - acc: 0.9573
# Epoch 12/50
# 9555/9555 [==============================] - 3s 286us/step - loss: 0.2018 - acc: 0.9559
# Epoch 13/50
# 9555/9555 [==============================] - 3s 303us/step - loss: 0.1923 - acc: 0.9622
# Epoch 14/50
# 9555/9555 [==============================] - 3s 295us/step - loss: 0.1860 - acc: 0.9620
# Epoch 15/50
# 9555/9555 [==============================] - 3s 277us/step - loss: 0.1832 - acc: 0.9632
# Epoch 16/50
# 9555/9555 [==============================] - 2s 255us/step - loss: 0.1766 - acc: 0.9621
# Epoch 17/50
# 9555/9555 [==============================] - 3s 272us/step - loss: 0.1664 - acc: 0.9647
# Epoch 18/50
# 9555/9555 [==============================] - 3s 302us/step - loss: 0.1670 - acc: 0.9678
# Epoch 19/50
# 9555/9555 [==============================] - 3s 287us/step - loss: 0.1674 - acc: 0.9666
# Epoch 20/50
# 9555/9555 [==============================] - 3s 304us/step - loss: 0.1592 - acc: 0.9682
# Epoch 21/50
# 9555/9555 [==============================] - 3s 279us/step - loss: 0.1655 - acc: 0.9679
# Epoch 22/50
# 9555/9555 [==============================] - 3s 300us/step - loss: 0.1504 - acc: 0.9707
# Epoch 23/50
# 9555/9555 [==============================] - 3s 284us/step - loss: 0.1492 - acc: 0.9699
# Epoch 24/50
# 9555/9555 [==============================] - 3s 281us/step - loss: 0.1515 - acc: 0.9691
# Epoch 25/50
# 9555/9555 [==============================] - 3s 304us/step - loss: 0.1492 - acc: 0.9708
# Epoch 26/50
# 9555/9555 [==============================] - 3s 322us/step - loss: 0.1373 - acc: 0.9725
# Epoch 27/50
# 9555/9555 [==============================] - 3s 329us/step - loss: 0.1408 - acc: 0.9728
# Epoch 28/50
# 9555/9555 [==============================] - 3s 322us/step - loss: 0.1339 - acc: 0.9750
# Epoch 29/50
# 9555/9555 [==============================] - 3s 291us/step - loss: 0.1331 - acc: 0.9739
# Epoch 30/50
# 9555/9555 [==============================] - 3s 293us/step - loss: 0.1228 - acc: 0.9772
# Epoch 31/50
# 9555/9555 [==============================] - 3s 290us/step - loss: 0.1356 - acc: 0.9730
# Epoch 32/50
# 9555/9555 [==============================] - 3s 278us/step - loss: 0.1317 - acc: 0.9767
# Epoch 33/50
# 9555/9555 [==============================] - 3s 293us/step - loss: 0.1251 - acc: 0.9762
# Epoch 34/50
# 9555/9555 [==============================] - 3s 312us/step - loss: 0.1230 - acc: 0.9778
# Epoch 35/50
# 9555/9555 [==============================] - 3s 286us/step - loss: 0.1268 - acc: 0.9774
# Epoch 36/50
# 9555/9555 [==============================] - 2s 260us/step - loss: 0.1229 - acc: 0.9755
# Epoch 37/50
# 9555/9555 [==============================] - 2s 253us/step - loss: 0.1172 - acc: 0.9775
# Epoch 38/50
# 9555/9555 [==============================] - 3s 321us/step - loss: 0.1160 - acc: 0.9771
# Epoch 39/50
# 9555/9555 [==============================] - 2s 253us/step - loss: 0.1175 - acc: 0.9795
# Epoch 40/50
# 9555/9555 [==============================] - 2s 239us/step - loss: 0.1198 - acc: 0.9773
# Epoch 41/50
# 9555/9555 [==============================] - 3s 331us/step - loss: 0.1151 - acc: 0.9798
# Epoch 42/50
# 9555/9555 [==============================] - 3s 359us/step - loss: 0.1074 - acc: 0.9802
# Epoch 43/50
# 9555/9555 [==============================] - 2s 221us/step - loss: 0.1058 - acc: 0.9804
# Epoch 44/50
# 9555/9555 [==============================] - 2s 219us/step - loss: 0.1102 - acc: 0.9779
# Epoch 45/50
# 9555/9555 [==============================] - 2s 230us/step - loss: 0.1057 - acc: 0.9794
# Epoch 46/50
# 9555/9555 [==============================] - 2s 242us/step - loss: 0.1036 - acc: 0.9813
# Epoch 47/50
# 9555/9555 [==============================] - 2s 236us/step - loss: 0.1078 - acc: 0.9803
# Epoch 48/50
# 9555/9555 [==============================] - 2s 225us/step - loss: 0.1008 - acc: 0.9820
# Epoch 49/50
# 9555/9555 [==============================] - 2s 217us/step - loss: 0.0978 - acc: 0.9823
# Epoch 50/50
# 9555/9555 [==============================] - 2s 215us/step - loss: 0.1054 - acc: 0.9789

# %%
# CNN model summary 
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 168, 10)           40
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 84, 10)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 82, 20)            620
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 41, 20)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 39, 30)            1830
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 19, 30)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 19, 30)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 570)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 170)               97070
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 170)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                3420
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 42
# =================================================================
# Total params: 103,022
# Trainable params: 103,022
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Score model on test data
score = model.evaluate(X_test, Y_test, verbose = 1)
labels = model.metrics_names
print(str(labels[0]) + ": " + str(score[0]))
print(str(labels[1]) + ": " + str(score[1]))
# Out:
# 3185/3185 [==============================] - 0s 140us/step
# loss: 0.06427600652891763
# acc: 0.9924646781789639

# %%
# Evaluate model with AUC-ROC score
y_score = model.predict(X_test)
metrics.roc_auc_score(Y_test, y_score)
# Out:
# 0.9995300173937488

# %%
# AUC - ROC Plot 
y_probs = model.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_probs)

fig = plt.figure(figsize = (5,5))
plt.plot(fpr, tpr)

# Labels
plt.xlabel('Specificity')
plt.ylabel('Sensitivity')
plt.title('ROC curve');

# %%
# Kaggle predictions dataframe and csv file
submission = pd.DataFrame()
submission['WnvPresent'] = model.predict_proba(X_test_kaggle_shaped)[:,1]
submission['Id'] = submission.index + 1
submission[['Id', 'WnvPresent']].to_csv('kaggle/submission_cnn.csv', index = False)

# %% [markdown]
# On Kaggle this model achieved a AUC-ROC score of 0.58692

# %% [markdown]
# #### Decision Tree Classifier

# %%
# Make a train-test split
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res)

# %%
# Gridsearch for optimal parameters
params = {
    'max_depth': [None, 2,3],
    'min_samples_split' : [2,3,4],
    'min_samples_leaf':[1,2,3],
    'max_features':[None, 'sqrt', 'log2']
}

gs_dtc = GridSearchCV(DecisionTreeClassifier(),params)
gs_dtc.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'max_depth': [None, 2, 3], 'min_samples_split': [2, 3, 4], 'min_samples_leaf': [1, 2, 3], 'max_features': [None, 'sqrt', 'log2']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
# Check out scores
print(gs_dtc.best_score_, gs_dtc.score(X_test, y_test), gs_dtc.best_params_)
# Out:
# 0.9714142928535732 0.9778110944527736 {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2}

# %%
# RoC score
y_hat = gs_dtc.predict(X_test)

metrics.roc_auc_score(y_test, y_hat)
# Out:
# 0.9778839192283832

# %%
# RoC Plot
y_probs = gs_dtc.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_probs)

fig = plt.figure(figsize = (5,5))
plt.plot(fpr, tpr)

# Labels
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve');

# %%
# Important coefs
coefs = pd.DataFrame(gs_dtc.best_estimator_.feature_importances_, index = X.columns, columns = ['Importance'])

axes = coefs.sort_values(by='Importance').plot(kind='barh',figsize = (10,10))

# %%
# Make kaggle submission
y_hat = gs_dtc.predict_proba(X_test_kaggle)
submission = pd.DataFrame(y_hat, columns = ['WnvPresent'])
submission['Id'] = submission.index + 1
submission[['Id', 'WnvPresent']].to_csv('kaggle/submission-dtc.csv', index=False)

# %% [markdown]
# This model scored 0.50794 on Kaggle.

# %% [markdown]
# #### Support Vector Classifier

# %%
# Make a train-test split
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res)

# %%
# Standardize our data for support vector analysis
ss = StandardScaler()
X_train_sc = ss.fit_transform(X_train)
X_test_sc = ss.transform(X_test)
X_test_kaggle_sc = ss.transform(X_test_kaggle)

# %%
# fit an untuned model
sv = SVC(probability=True, C=1.0)
sv.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
# Check accuracy on training data
sv.score(X_train, y_train)
# Out:
# 0.8926536731634183

# %%
# Check accuracy on test data
sv.score(X_test, y_test)
# Out:
# 0.8920539730134932

# %% [markdown]
# Looks like we didn't overfit.

# %%
# Make predictions and check RoC score
y_hat = sv.predict(X_test)

metrics.roc_auc_score(y_test, y_hat)
# Out:
# 0.8914912295857323

# %%
# RoC Plot
y_probs = sv.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_probs)

fig = plt.figure(figsize = (5,5))
plt.plot(fpr, tpr)

# Labels
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve');

# %%
# GridSearch for optimal kernel and C value

params = {
    'C' : [.5, 1.0, 1.5],
    'kernel' : ['rbf', 'linear','sigmoid' ]
}
gs_sv = GridSearchCV(SVC(probability=True), params)
gs_sv.fit(X_train_sc, y_train)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'C': [0.5, 1.0, 1.5], 'kernel': ['rbf', 'linear', 'sigmoid']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
# Look at scores
print(gs_sv.best_score_, gs_sv.score(X_test_sc, y_test), gs_sv.best_params_)
# Out:
# 0.9366316841579211 0.9481259370314843 {'C': 1.5, 'kernel': 'rbf'}

# %%
# Check out RoC score
y_hat = gs_sv.predict(X_test_sc)
metrics.roc_auc_score(y_test,y_hat)
# Out:
# 0.947409909423498

# %%
# RoC Plot
y_probs = gs_sv.predict_proba(X_test_sc)[:, 1]
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_probs)

fig = plt.figure(figsize = (5,5))
plt.plot(fpr, tpr)

# Labels
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve');

# %% [markdown]
# The grid-searched SVC has a better RoC score.

# %%
# Kaggle submission
y_hat = gs_sv.predict_proba(X_test_kaggle_sc)
submission = pd.DataFrame(y_hat, columns = ['WnvPresent'])
submission['Id'] = submission.index + 1
submission[['Id', 'WnvPresent']].to_csv('kaggle/submission-svc.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-d9ca2428aa15> in <module>()
#       1 # Kaggle submission
# ----> 2 y_hat = gs_sv.predict_proba(X_test_kaggle_sc)
#       3 submission = pd.DataFrame(y_hat, columns = ['WnvPresent'])
#       4 submission['Id'] = submission.index + 1
#       5 submission[['Id', 'WnvPresent']].to_csv('submission-svc.csv', index=False)
#
# NameError: name 'gs_sv' is not defined

# %% [markdown]
# This model scored 0.50000 on Kaggle (yikes)

# %% [markdown]
# #### Adaboost (Decision Tree Classifier)

# %%
# Adaboost a decision tree classifier
ada_dtc = AdaBoostClassifier(base_estimator = DecisionTreeClassifier())
ada_dtc.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=50, random_state=None)

# %%
# Check RoC score
y_hat = ada_dtc.predict(X_test)
print(metrics.roc_auc_score(y_test, y_hat))
# Out:
# 0.9801233098793322

# %%
# Plot RoC curve
y_probs = ada_dtc.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_probs)

fig = plt.figure(figsize = (5,5))
plt.plot(fpr, tpr)

# Labels
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve');

# %%
# Kaggle submission
y_hat = ada_dtc.predict_proba(X_test_kaggle)
submission = pd.DataFrame(y_hat, columns = ['WnvPresent'])
submission['Id'] = submission.index + 1
submission[['Id', 'WnvPresent']].to_csv('kaggle/submission-ada-dtc.csv', index=False)

# %% [markdown]
# This model scored 0.52478 on Kaggle.

# %% [markdown]
# #### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.9871180347513481

# %%
y_probs = rf.predict_proba(X_test)[:, 1]

# %%
fpr, tpr, _ = metrics.roc_curve(y_test, y_probs)

fig = plt.figure(figsize = (5,5))
plt.plot(fpr, tpr)

# Labels
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve');

# %% [markdown]
# #### Extra Trees Classifier

# %%
et = ExtraTreesClassifier()
et.fit(X_train,y_train)
et.score(X_test,y_test)
# Out:
# 0.9943079688436189

# %%
y_probs = et.predict_proba(X_test)[:, 1]

# %%
fpr, tpr, _ = metrics.roc_curve(y_test, y_probs)

fig = plt.figure(figsize = (5,5))
plt.plot(fpr, tpr)

# Labels
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve');

# %% [markdown]
# #### Deep Neural Network

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
from keras import regularizers
from keras.layers import Dropout

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res , stratify = y_res) ## We want to stratify for classification

ss = StandardScaler()
ss.fit(X_train)

X_train_ss = ss.transform(X_train)
X_test_ss = ss.transform(X_test)
X_test_kaggle_sc = ss.transform(X_test_kaggle)

# %%
model = Sequential()
model.add(Dense(25, activation = 'relu', input_dim = X_res.shape[1],kernel_regularizer=regularizers.l2(0.01)))
model.add(Dropout(0.15))
model.add(Dense(25, activation = 'relu', input_dim = 25))
model.add(Dropout(0.15))
model.add(Dense(10, activation = 'relu', input_dim = 25))
model.add(Dense(1, activation = 'sigmoid')) ## Output layer

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
history = model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs = 50, verbose = 1)
# Out:
# Train on 10011 samples, validate on 3338 samples
# Epoch 1/50
# 10011/10011 [==============================] - 2s 182us/step - loss: 1.4966 - acc: 0.5288 - val_loss: 0.7246 - val_acc: 0.6345
# Epoch 2/50
# 10011/10011 [==============================] - 1s 83us/step - loss: 0.7441 - acc: 0.5566 - val_loss: 0.7079 - val_acc: 0.5294
# Epoch 3/50
# 10011/10011 [==============================] - 1s 74us/step - loss: 0.7157 - acc: 0.5641 - val_loss: 0.7034 - val_acc: 0.5920
# Epoch 4/50
# 10011/10011 [==============================] - 1s 71us/step - loss: 0.7007 - acc: 0.5906 - val_loss: 0.6656 - val_acc: 0.6375
# Epoch 5/50
# 10011/10011 [==============================] - 1s 77us/step - loss: 0.6873 - acc: 0.6101 - val_loss: 0.6460 - val_acc: 0.7070
# Epoch 6/50
# 10011/10011 [==============================] - 1s 65us/step - loss: 0.6690 - acc: 0.6351 - val_loss: 0.6459 - val_acc: 0.6705
# Epoch 7/50
# 10011/10011 [==============================] - 1s 66us/step - loss: 0.6575 - acc: 0.6552 - val_loss: 0.5930 - val_acc: 0.7418
# Epoch 8/50
# 10011/10011 [==============================] - 1s 74us/step - loss: 0.6325 - acc: 0.6930 - val_loss: 0.5722 - val_acc: 0.7915
# Epoch 9/50
# 10011/10011 [==============================] - 1s 83us/step - loss: 0.6023 - acc: 0.7225 - val_loss: 0.5326 - val_acc: 0.7987
# Epoch 10/50
# 10011/10011 [==============================] - 1s 86us/step - loss: 0.5862 - acc: 0.7379 - val_loss: 0.5031 - val_acc: 0.7918
# Epoch 11/50
# 10011/10011 [==============================] - 1s 86us/step - loss: 0.5688 - acc: 0.7490 - val_loss: 0.4982 - val_acc: 0.7978
# Epoch 12/50
# 10011/10011 [==============================] - 1s 84us/step - loss: 0.5533 - acc: 0.7584 - val_loss: 0.5011 - val_acc: 0.8128
# Epoch 13/50
# 10011/10011 [==============================] - 1s 83us/step - loss: 0.5479 - acc: 0.7625 - val_loss: 0.4949 - val_acc: 0.8146
# Epoch 14/50
# 10011/10011 [==============================] - 1s 85us/step - loss: 0.5352 - acc: 0.7696 - val_loss: 0.4619 - val_acc: 0.8238
# Epoch 15/50
# 10011/10011 [==============================] - 1s 86us/step - loss: 0.5312 - acc: 0.7696 - val_loss: 0.4540 - val_acc: 0.8304
# Epoch 16/50
# 10011/10011 [==============================] - 1s 81us/step - loss: 0.5177 - acc: 0.7770 - val_loss: 0.4616 - val_acc: 0.8223
# Epoch 17/50
# 10011/10011 [==============================] - 1s 85us/step - loss: 0.5228 - acc: 0.7695 - val_loss: 0.4724 - val_acc: 0.8182
# Epoch 18/50
# 10011/10011 [==============================] - 1s 84us/step - loss: 0.5129 - acc: 0.7769 - val_loss: 0.4354 - val_acc: 0.8238
# Epoch 19/50
# 10011/10011 [==============================] - 1s 85us/step - loss: 0.5062 - acc: 0.7816 - val_loss: 0.4588 - val_acc: 0.8104
# Epoch 20/50
# 10011/10011 [==============================] - 1s 77us/step - loss: 0.5039 - acc: 0.7807 - val_loss: 0.4757 - val_acc: 0.8038
# Epoch 21/50
# 10011/10011 [==============================] - 1s 71us/step - loss: 0.5001 - acc: 0.7826 - val_loss: 0.4240 - val_acc: 0.8331
# Epoch 22/50
# 10011/10011 [==============================] - 1s 72us/step - loss: 0.4996 - acc: 0.7841 - val_loss: 0.4612 - val_acc: 0.8209
# Epoch 23/50
# 10011/10011 [==============================] - 1s 79us/step - loss: 0.4968 - acc: 0.7882 - val_loss: 0.4289 - val_acc: 0.8226
# Epoch 24/50
# 10011/10011 [==============================] - 1s 62us/step - loss: 0.4957 - acc: 0.7898 - val_loss: 0.4207 - val_acc: 0.8352
# Epoch 25/50
# 10011/10011 [==============================] - 1s 65us/step - loss: 0.4945 - acc: 0.7841 - val_loss: 0.4267 - val_acc: 0.8358
# Epoch 26/50
# 10011/10011 [==============================] - 1s 68us/step - loss: 0.4954 - acc: 0.7813 - val_loss: 0.4179 - val_acc: 0.8340
# Epoch 27/50
# 10011/10011 [==============================] - 1s 76us/step - loss: 0.4928 - acc: 0.7866 - val_loss: 0.4169 - val_acc: 0.8301
# Epoch 28/50
# 10011/10011 [==============================] - 1s 86us/step - loss: 0.4856 - acc: 0.7867 - val_loss: 0.4240 - val_acc: 0.8328
# Epoch 29/50
# 10011/10011 [==============================] - 1s 80us/step - loss: 0.4933 - acc: 0.7857 - val_loss: 0.4276 - val_acc: 0.8367
# Epoch 30/50
# 10011/10011 [==============================] - 1s 86us/step - loss: 0.4903 - acc: 0.7875 - val_loss: 0.4311 - val_acc: 0.8397
# Epoch 31/50
# 10011/10011 [==============================] - 1s 87us/step - loss: 0.4994 - acc: 0.7793 - val_loss: 0.4135 - val_acc: 0.8397
# Epoch 32/50
# 10011/10011 [==============================] - 1s 82us/step - loss: 0.4918 - acc: 0.7840 - val_loss: 0.4222 - val_acc: 0.8370
# Epoch 33/50
# 10011/10011 [==============================] - 1s 79us/step - loss: 0.4837 - acc: 0.7888 - val_loss: 0.4202 - val_acc: 0.8343
# Epoch 34/50
# 10011/10011 [==============================] - 1s 75us/step - loss: 0.4806 - acc: 0.7921 - val_loss: 0.4201 - val_acc: 0.8310
# Epoch 35/50
# 10011/10011 [==============================] - 1s 71us/step - loss: 0.4810 - acc: 0.7925 - val_loss: 0.4237 - val_acc: 0.8346
# Epoch 36/50
# 10011/10011 [==============================] - 1s 73us/step - loss: 0.4828 - acc: 0.7901 - val_loss: 0.4271 - val_acc: 0.8430
# Epoch 37/50
# 10011/10011 [==============================] - 1s 67us/step - loss: 0.4791 - acc: 0.7928 - val_loss: 0.4086 - val_acc: 0.8433
# Epoch 38/50
# 10011/10011 [==============================] - 1s 69us/step - loss: 0.4751 - acc: 0.7950 - val_loss: 0.4369 - val_acc: 0.8220
# Epoch 39/50
# 10011/10011 [==============================] - 1s 80us/step - loss: 0.4875 - acc: 0.7893 - val_loss: 0.4229 - val_acc: 0.8176
# Epoch 40/50
# 10011/10011 [==============================] - 1s 85us/step - loss: 0.4840 - acc: 0.7896 - val_loss: 0.4431 - val_acc: 0.8229
# Epoch 41/50
# 10011/10011 [==============================] - 1s 81us/step - loss: 0.4751 - acc: 0.7922 - val_loss: 0.4303 - val_acc: 0.8313
# Epoch 42/50
# 10011/10011 [==============================] - 1s 84us/step - loss: 0.4823 - acc: 0.7865 - val_loss: 0.4136 - val_acc: 0.8388
# Epoch 43/50
# 10011/10011 [==============================] - 1s 87us/step - loss: 0.4829 - acc: 0.7936 - val_loss: 0.4160 - val_acc: 0.8232
# Epoch 44/50
# 10011/10011 [==============================] - 1s 86us/step - loss: 0.4856 - acc: 0.7897 - val_loss: 0.4237 - val_acc: 0.8268
# Epoch 45/50
# 10011/10011 [==============================] - 1s 87us/step - loss: 0.4814 - acc: 0.7962 - val_loss: 0.4271 - val_acc: 0.8412
# Epoch 46/50
# 10011/10011 [==============================] - 1s 81us/step - loss: 0.4839 - acc: 0.7955 - val_loss: 0.4323 - val_acc: 0.8442
# Epoch 47/50
# 10011/10011 [==============================] - 1s 80us/step - loss: 0.4794 - acc: 0.7952 - val_loss: 0.3971 - val_acc: 0.8475
# Epoch 48/50
# 10011/10011 [==============================] - 1s 86us/step - loss: 0.4807 - acc: 0.7956 - val_loss: 0.4513 - val_acc: 0.8214
# Epoch 49/50
# 10011/10011 [==============================] - 1s 77us/step - loss: 0.4742 - acc: 0.8019 - val_loss: 0.4105 - val_acc: 0.8388
# Epoch 50/50
# 10011/10011 [==============================] - 1s 68us/step - loss: 0.4780 - acc: 0.7950 - val_loss: 0.3944 - val_acc: 0.8487

# %%
y_probs = model.predict(X_test)

# %%
metrics.roc_auc_score(y_test, y_probs)
# Out:
# 0.9204778467025784

# %%
fpr, tpr, _ = metrics.roc_curve(y_test, y_probs)

fig = plt.figure(figsize = (5,5))
plt.plot(fpr, tpr)

# Labels
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve');

# %%
plt.plot(history.history['loss'], label = 'train loss')
plt.plot(history.history['val_loss'], label = 'test loss')
plt.legend
# Out:
# <function matplotlib.pyplot.legend>
